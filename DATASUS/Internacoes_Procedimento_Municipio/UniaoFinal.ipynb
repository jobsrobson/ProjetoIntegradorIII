# %%
# União final dos 4 arquivos de internações por procedimento e município

import pandas as pd
import numpy as np

# %%
# Abrir os arquivos

# 2019
df_2019 = pd.read_csv('C:\\Users\\jobsr\\OneDrive\\Documentos\\GitHub\\ProjetoIntegradorIII\\DATASUS\\Internacoes_Procedimento_Municipio\\2019\\Tratados\\2019_T.csv', sep=';', encoding='latin-1')
df_2020 = pd.read_csv('C:\\Users\\jobsr\\OneDrive\\Documentos\\GitHub\\ProjetoIntegradorIII\\DATASUS\\Internacoes_Procedimento_Municipio\\2020\\Tratados\\2020_T.csv', sep=';', encoding='latin-1')
df_2021 = pd.read_csv('C:\\Users\\jobsr\\OneDrive\\Documentos\\GitHub\\ProjetoIntegradorIII\\DATASUS\\Internacoes_Procedimento_Municipio\\2021\\Tratados\\2021_T.csv', sep=';', encoding='latin-1')
df_2022 = pd.read_csv('C:\\Users\\jobsr\\OneDrive\\Documentos\\GitHub\\ProjetoIntegradorIII\\DATASUS\\Internacoes_Procedimento_Municipio\\2022\\Tratados\\2022_T.csv', sep=';', encoding='latin-1')

# %%
# Unir as bases
df = pd.concat([df_2019, df_2020, df_2021, df_2022])

# %%
df.head()
# Out:
#     Ano  Trimestre          UID  Codigo_Municipio         Nome_Municipio  \
# 0  2019          1  20191110001            110001  ALTA FLORESTA D'OESTE
# 1  2019          1  20191110002            110002              ARIQUEMES
# 2  2019          1  20191110003            110003                 CABIXI
# 3  2019          1  20191110004            110004                 CACOAL
# 4  2019          1  20191110005            110005             CEREJEIRAS
#
#    Coleta_Material_0201  Diagnostico_Endoscopia_0209  \
# 0                     0                            0
# 1                     0                            0
# 2                     0                            0
# 3                     3                            0
# 4                     0                            0
#
#    Metodos_Diagnosticos_Especialidades_0211  \
# 0                                         0
# 1                                         0
# 2                                         0
# ...

# %%
# Salvar o arquivo
df.to_csv('C:\\Users\\jobsr\\OneDrive\\Documentos\\GitHub\\ProjetoIntegradorIII\\DATASUS\\Internacoes_Procedimento_Municipio\\2019-2022.csv', sep=';', encoding='latin-1', index=False)
