# %%
import pandas as pd
import numpy as np

# %%
# Importar dados
df = pd.read_csv('C:\\Users\\jobsr\\OneDrive\\Documentos\\GitHub\\ProjetoIntegradorIII\\DATASUS\\Municipios_IBGE_BR\\municipios_ibge.CSV', sep=';', encoding='latin-1')

# %%
df.head()
# Out:
#               ConcatUF+Mun    IBGE    IBGE7  UF              Município  \
# 0  ROAlta Floresta D'oeste  110001  1100015  RO  Alta Floresta D´oeste
# 1              ROAriquemes  110002  1100023  RO              Ariquemes
# 2                 ROCabixi  110003  1100031  RO                 Cabixi
# 3                 ROCacoal  110004  1100049  RO                 Cacoal
# 4             ROCerejeiras  110005  1100056  RO             Cerejeiras
#
#          Região  População 2010       Porte Capital
# 0  Região Norte         24392.0  Pequeno II     NaN
# 1  Região Norte         90353.0       Médio     NaN
# 2  Região Norte          6313.0   Pequeno I     NaN
# 3  Região Norte         78574.0       Médio     NaN
# 4  Região Norte         17029.0   Pequeno I     NaN

# %%
# Drop da coluna ConcatUF+Mun

df.drop('ConcatUF+Mun', axis=1, inplace=True)

# %%
df.head()
# Out:
#      IBGE    IBGE7  UF              Município        Região  População 2010  \
# 0  110001  1100015  RO  Alta Floresta D´oeste  Região Norte         24392.0
# 1  110002  1100023  RO              Ariquemes  Região Norte         90353.0
# 2  110003  1100031  RO                 Cabixi  Região Norte          6313.0
# 3  110004  1100049  RO                 Cacoal  Região Norte         78574.0
# 4  110005  1100056  RO             Cerejeiras  Região Norte         17029.0
#
#         Porte Capital
# 0  Pequeno II     NaN
# 1       Médio     NaN
# 2   Pequeno I     NaN
# 3       Médio     NaN
# 4   Pequeno I     NaN

# %%
# Salvar arquivo CSV

df.to_csv('C:\\Users\\jobsr\\OneDrive\\Documentos\\GitHub\\ProjetoIntegradorIII\\DATASUS\\Municipios_IBGE_BR\\Municipios_IBGE_BR.CSV', sep=';', encoding='latin-1', index=False)
